# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5845.9/8062.4 GB disk)

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/kaggle/input/catdog epochs=300 patience=22
# Out:
# ...
# 100%|███████████████████████████████████████| 5.31M/5.31M [00:00<00:00, 270MB/s]
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=classify mode=predict model=/kaggle/working/runs/classify/train/weights/best.pt source=/kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/1.jpg: 224x224 cats 1.00, dogs 0.00, 3.1ms
# image 2/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/10.jpg: 224x224 cats 1.00, dogs 0.00, 4.2ms
# image 3/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/11.jpg: 224x224 cats 1.00, dogs 0.00, 3.2ms
# image 4/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/12.jpg: 224x224 cats 1.00, dogs 0.00, 3.0ms
# image 5/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/13.jpg: 224x224 cats 1.00, dogs 0.00, 3.2ms
# image 6/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/14.jpg: 224x224 cats 1.00, dogs 0.00, 3.2ms
# image 7/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/cat/15.jpg: 224x224 cats 1.00, dogs 0.00, 3.2ms
# ...

# %%
# !yolo task=classify mode=predict model=/kaggle/working/runs/classify/train/weights/best.pt source=/kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/1.jpg: 224x224 dogs 1.00, cats 0.00, 3.3ms
# image 2/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/10.jpg: 224x224 dogs 1.00, cats 0.00, 3.7ms
# image 3/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/11.jpg: 224x224 dogs 1.00, cats 0.00, 4.1ms
# image 4/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/12.jpg: 224x224 dogs 1.00, cats 0.00, 3.2ms
# image 5/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/13.jpg: 224x224 dogs 1.00, cats 0.00, 3.3ms
# image 6/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/14.jpg: 224x224 dogs 1.00, cats 0.00, 3.2ms
# image 7/32 /kaggle/input/cats-and-dogs-40/catsAndDogs40/train/dog/15.jpg: 224x224 dogs 1.00, cats 0.00, 4.0ms
# ...
